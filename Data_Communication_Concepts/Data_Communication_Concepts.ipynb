# %% [markdown]
# # ***KEE***
#
#   * Key information
#   * Engaging
#   * Easy to understand
#
# # ***Write a precise and clear report***
#   * Concise
#   * Precise
#   * Avoid misleading and confusion
#
# # ***The story begins***
#
# You recently started working as a data scientist at a company named Communicatb. For your first project, you and your team need to analyze churn customer data for a cell phone company. The goal is to predict their behavior and help develop a program to retain customers.
#
# Your team lead knows you are an expert on storytelling. She asks you to explain to the team why crafting a compelling story is important when delivering results. You write down a list of reasons to be prepared.
#
# 1. It will be easier for the audience to remember an anecdote on why customers churn than the correlation coefficients between customer traits.
#
# 2. Your findings will be better aligned with change-adverse stakeholder expectations. They will be most likely to implement the program to retain customers.
#
# 3. The marketing team will have a better understanding of the impact of your model. It is central since they are creating the retention program.
#
# Data is the foundation of your story. So you need to make sure you are telling a story based on reliable and accurate results!

# %% [markdown]
# # ***Building a story***
#
# You nailed it! Your explanation of why stories are efficient when conveying insights went very well! Now, your team lead would like you to give a short presentation. You're going explain the different steps involved in telling a story with data to the team. It will be the starting point for delivering the results of the churn project when ready.
#
# You know it is an important task. To prepare your talk, you need to remember the do's and dont's of data storytelling.
#
# ### **Do's**
#
# 1. Linear telling: Present one supporting points after each point so they reach conclusion linearly.
# 2. Driving change: Present why it is beneficial around some measurble metrics, e.g., profit, if the actions are implemented.
# 3. Convincing: connect the results to the planned actions.
#
# ### **Dont's**
# 1. Include data from successful actions by others
# 2. Build one story and present it to the managers and technical staffs
# 3. Include all findings

# %% [markdown]
# # ***ADEPT***
#
# * **A**nalogy
# * **D**iagram
# * **E**xample
# * **P**lain English
# * **T**echnical definition
#
# # ***Narrative Structures***
#
# ![image.png](data:image/png;base64,...)
#
# * What **motivated** analysis
# * What has **changed** as to why the analysis must be done
# * Who is the **focus** of the analysis
#
# ![image.png](data:image/png;base64,...)
#
# * What caused the problem?
#   * Only relevant information, not detailed data
#
# ![image.png](data:image/png;base64,...)
#
# * Add **supporting evidence**
#   * Only if it helps explain the cause of problems
#
# ![image.png](data:image/png;base64,...)
#
# * Central findings
#   * **What could happen if nothing has changed**
#
#   ![image.png](data:image/png;base64,...)
#
# * Suggested solutions
#
# # ***Building Narrative***
#
# * **Change over time**
#
# * **Correlation**
#
# * **Comparison**
#
# * **Clustering**
#
# A compelling narrative is key to presenting relevant insights to your target audience in a meaningful and impactful way.  You should shape the narrative to your target audience, so showing only key points or findings is a good practice. But remember that the story should always be based on strong and ***trustworthy*** results.
#
# # ***Structured to impact (Example)***
#
# You analyzed the data and built your model. You followed the steps for storytelling. Now, it's time to structure your story to have an impact at the decision-making level.
#
# 1. ใช้กราฟเส้น แสดงให้เห็นถึงปัญหาที่ได้เกิดขึ้น
# 2. ใช้กราฟกล่อง แสดงให้เห็นว่า ตัวแปรต้นกลุ่มไหนเป็นตัวก่อปัญหา
#   * เช่น คนเลิกเป็นสมาชิกเยอะขึ้น เพราะกลุ่ม A เพิ่มขึ้น
#   * แสดงข้อมูลสนับสนุนว่า ภายในกลุ่ม A ด้วยกันเอง มีอัตราส่วนที่เลิกเป็นสมาชิกเยอะขึ้น
# 3. ใช้แบบจำลองพยากรณ์ออกมาว่า ตัวแปรต้นตัวใดมีความสำคัญมากที่สุดต่อปัญหาที่เกิดขึ้น
# 4. เสนอทางเลือก พร้อมข้อมูลของสิ่งที่จะเกิด ถ้าทำตามทางเลือกนั้นๆ

# %% [markdown]
# # ***The truth about salaries***
#
# Your project manager asks you to work on a new internal project. The goal is to analyze a database with employee salaries.
#
# After doing an exhaustive exploratory data analysis, you have to present your findings to the human resources team. They want to compare San Francisco salary growth to the one at the company; ***they need to understand how to forecast salaries*** for the next year. You are about to copy the graphs from your analysis. Your manager reminds you to ***select the right data*** for your stakeholders.
#
# * The human resource team would likely be interested in knowing how the average salary has been increasing in the last 10 years in San Francisco.
# * The human resource team has no knowledge of data analysis techniques, so code shouldn't be included when listing the top 5 job titles.
# * Select categorical data, such as the salaries on the top 10 rated companies in industry the company evolves in, that provides context to support the idea of the increased salaries.
#
# **Too much information** can be overwhelming and can cloud the understanding of the salary increase rate.
#
# # ***p-values***
#
# Always remember that **p-value** is not the sole indicator of a truth. You should evaluate carefully its values and consider alternatives.
#
# # ***Technical vs Non-technical***
#
# ## **Technical**
#   * Use density plot
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ## **Non-technical**
#   * Use histogram
#
#
#   ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***Effective visualization presentation***
#
# 1. ต้องมีชื่อกราฟ สั้น ได้ใจความ
#
# ![image.png](data:image/png;base64,...)
#
#   * ต้องมีแกน x แกน y
#
#
# ![image.png](data:image/png;base64,...)
#
#
# 2. ตอบคำถามพื้นฐาน เช่น ข้อมูลมาจากไหน ทำไมจึงนำเสนอข้อมูลนี้
# 3. อธิบายกราฟว่า กราฟนำเสนอข้อมูลอะไร
# 4. อธิบายต่อว่า กราฟนี้ มันเกี่ยวข้องยังไงกับกราฟต่อๆไป หรือเกี่ยวข้องกับการตัดสินใจที่จะทำอย่างไร
#
# # ***Showing visulization steps***
#
# 1. เริ่มด้วยหัวเรื่องของกราฟ
# 2. อธิบายว่า ข้อมูลมาจากไหน
# 3. อธิบายภาพรวม แล้วจึงอธิบายจุดย่อย
# 4. อธิบายว่า ข้อมูลนี้สำคัญอย่างไรกับองค์กร

# %% [markdown]
# # ***Report Structure***
#
# 1. Introduction
#   * Purpose
#   * Why the analysis is performed
#     * e.g., why profit is lower, more negative feedback
#   * Questions of analysis
#     * e.g., factors affecting ...
#
# 2. Body
#   * Data
#     * Descriptions of relevant variables and tables
#   * Methods
#     * e.g., NLP and Random Forest
#   * Analysis
#     * Visuals with most common words
#   * Results
#     * Description and visuals
#
# 3. Conclusions
#   * Restate questions
#   * Summarize important results
#   * Add recommendations
#
#   ## ***ตัวอย่าง***
#
#   1. จุดประสงค์ของรายงานฉบับนี้เพื่อ
#   2. รวบรวมข้อมูลจาก
#   3. ดำเนินการกับข้อมูลอย่างไร ใช้อัลกอริธึมใด
#   4. กราฟแสดงผลมาสื่อว่าอะไร
#   5. แบบจำลองมีความแม่นยำในการพยากรณ์ขนาดไหน ปัจจัยใดมีความเชื่อมโยงกับตัวแปรตาม
#   6. สรุป ควรมีมาตรการอะไรเพื่อทำให้สถานการณ์ดีขึ้นากกว่าที่เป็นอยู่ ณ ตอนนี้
#
#
# # ***Summary report structure***
#
# 1. Introduction
#   * Purpose
#   * Contextual information
#   * Question of analysis
# 2. Body
#   * Data
#   * Results: Key ,ndings
# 3. Conclusions
#   * Restate question
#   * Central insight
#   * Add recommendations
#
#   # ***วลีต้องห้าม***
#
# * It is interesting to note that
# * The fact that
# * It should be pointed out that
# * It is well known that
# * It is obvious that
# * Introduce a new
# * Done previously
#
# # ***สรรพนาม***
#
# * อย่าใช้ This, That, It บ่อย ให้เฉพาะเจาะจงไปเลยว่าพูดถึงอะไร
#
# # ***อย่าใช้ passive voice ใน business report ถ้าไม่จำเป็น*** (ถ้าเขียนส่งวารสาร อันนั้นโอเค)

# %% [markdown]
# # ***Purpose of Presentation***
#
# * Informative
# * Instructional
# * Persuasive
#
# # ***Oral Presentation***
#
# * **Opening Statement**
#   * Capture attention
#
# * **Central Message**
#   * One sentence
#
# * **Closing Statement**
#   * Summarize and support central message
#
#
# # ***Structure of Oral Presentation***
#
# 1. **Introduction**
#   * Provide background information
#   * Catch audience attention
#   * Glimpse of presentation content
#
# 2. **Methods, analysis and model outputs**
#
# 3. **Conclusions and takeaways**
#   * Refers back to the introduction
#   * Contains call-to-action statement or/and next steps

# %% [markdown]
# # ***Outline***
#
# 1. Reason for analysis
# 2. Exploratory analysis
# 3. Model analysis
# 4. Conclusions
# 5. Follow-up actions
#
# # ***Slides***
#
# * One message per slide!
# * อยากใส่กราฟเกิน 2 ต่อสไลด์
# * ค่อยๆใส่ findings มา อย่าเอาไปใส่ตอนท้ายรวดเดียว
